# %%
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
from tinkoff.invest import Client, CandleInterval
from decimal import Decimal

# %%
token = 'ваш тиньков токен (api 2.0)'

# %%
def units_nano_convert(d):
    # https://github.com/Tinkoff/invest-python/issues/45
    nano = d['nano'] / Decimal("10e8")
    price = d['units'] + float(nano)
    return price

# %%
# Берём все тикеты IMOEX отсюда
table = pd.read_html('https://www.tinkoff.ru/invest/etfs/TMOS/structure/details/')      

df = table[0]
df = df.rename(columns={'Название': 'name'})
df = df[df['name'] != 'Денежные средстваВалюта']
df['name'] = df['name'].str[:-5]

# %%
with Client(token) as client:
    shares = client.instruments.shares()

all_stocks = pd.DataFrame(shares.instruments)

df = pd.merge(df, all_stocks, how='left', on='name', sort=True)

df['min_price_increment'] = df['min_price_increment'].apply(units_nano_convert)

# %%
# Текущие цены акций
with Client(token) as client:
    last_prices = client.market_data.get_last_prices(figi=df['figi'].to_list())

last_prices = pd.DataFrame(last_prices.last_prices)

last_prices['price'] = last_prices['price'].apply(units_nano_convert)


df = last_prices.merge(df, on='figi')

df = df[['name', 'ticker', 'figi', 'lot', 'price', 'min_price_increment', 'currency']]

# %%
df = df[df['currency'] != 'usd']

# %%
# Считаем для стартового капитала в 10 тыс рублей
capital = 10000

df['lot_price'] = df['lot'] * df['price']
df['shares_available'] = capital // df['lot_price']
df['profit'] = df['shares_available']  * df['min_price_increment'] * df['lot']

# %%
df = df.sort_values(by=['profit'], ascending=False)
df.index = np.arange(1, len(df) + 1)

# %%
df
# Out:
#                                         name ticker          figi    lot  \
# 1                                  En+ Group   ENPG  BBG000RMWQD4      1
# 2                                   Аэрофлот   AFLT  BBG004S683W7     10
# 3                          Petropavlovsk PLC   POGR  BBG00VPKLPX4    100
# 4                          Ozon Holdings PLC   OZON  BBG00Y91R9T3      1
# 5                                         VK   VKCO  BBG00178PGX3      1
# 6                         ГДР X5 RetailGroup   FIVE  BBG00JXPFBN0      1
# 7         Татнефть - привилегированные акции  TATNP  BBG004S68829      1
# 8                                   Татнефть   TATN  BBG004RVFFC0      1
# 9                                   Банк ВТБ   VTBR  BBG004730ZJ9  10000
# 10                           Fix Price Group   FIXP  BBG00ZHCX1X2      1
# 11                               Детский Мир   DSKY  BBG000BN56Q9     10
# 12                                       МТС   MTSS  BBG004S681W1     10
# 13                             Интер РАО ЕЭС   IRAO  BBG004S68473    100
# 14                                   ФСК ЕЭС   FEES  BBG00475JZZ6  10000
# 15                                   НОВАТЭК   NVTK  BBG00475KKY8      1
# 16                            Сургутнефтегаз   SNGS  BBG0047315D0    100
# 17                                       МКБ   CBOM  BBG009GSYN76    100
# 18                                 TCS Group   TCSG  BBG00QPYJ5H0      1
# 19                                Северсталь   CHMF  BBG00475K6C3      1
# 20                                       ПИК   PIKK  BBG004S68BH6      1
# 21                                Ростелеком   RTKM  BBG004S682Z6     10
# 22                Globaltrans Investment PLC   GLTR  BBG000VFX6Y4      1
# 23  Сургутнефтегаз - привилегированные акции  SNGSP  BBG004S681M2    100
# 24                                  Роснефть   ROSN  BBG004731354      1
# 25                                 Polymetal   POLY  BBG004PYF2N3      1
# 26                                  РусГидро   HYDR  BBG00475K2X9   1000
# 27                                    АЛРОСА   ALRS  BBG004S68B31     10
# 28                                      НЛМК   NLMK  BBG004S681B4     10
# 29  Магнитогорский металлургический комбинат   MAGN  BBG004S68507     10
# 30                          Московская Биржа   MOEX  BBG004730JJ5     10
# 31                                    Магнит   MGNT  BBG004RVFCY3      1
# 32                                    ЛУКОЙЛ   LKOH  BBG004731032      1
# 33                                    Yandex   YNDX  BBG006L8G4H1      1
# 34                                   ФосАгро   PHOR  BBG004S689R0      1
# 35                                 Сбер Банк   SBER  BBG004730N88     10
# 36       Сбер Банк - привилегированные акции  SBERP  BBG0047315Y7     10
# 37                               АФК Система   AFKS  BBG004S68614    100
# 38                                     РУСАЛ   RUAL  BBG008F2T3T2     10
# 39                                   Газпром   GAZP  BBG004730RP0     10
# 40                              Полюс Золото   PLZL  BBG000R607Y3      1
# 41                         Норильский никель   GMKN  BBG004731489      1
# 42      Транснефть - привилегированные акции  TRNFP  BBG00475KHX6      1
#
#            price  min_price_increment currency  lot_price  shares_available  \
# 1      688.00000             0.500000      rub     688.00              14.0
# 2       30.62000             0.020000      rub     306.20              32.0
# 3        8.13500             0.005000      rub     813.50              12.0
# 4     1000.00000             0.500000      rub    1000.00              10.0
# 5      416.80000             0.200000      rub     416.80              23.0
# 6     1107.50000             0.500000      rub    1107.50               9.0
# 7      310.40000             0.100000      rub     310.40              32.0
# 8      359.70000             0.100000      rub     359.70              27.0
# 9        0.01881             0.000005      rub     188.10              53.0
# 10     383.20000             0.100000      rub     383.20              26.0
# 11      74.00000             0.020000      rub     740.00              13.0
# 12     188.05000             0.050000      rub    1880.50               5.0
# 13       2.43000             0.000500      rub     243.00              41.0
# 14       0.09448             0.000020      rub     944.80              10.0
# 15     970.20000             0.200000      rub     970.20              10.0
# 16      22.69000             0.005000      rub    2269.00               4.0
# 17       4.76300             0.001000      rub     476.30              20.0
# 18    2270.00000             0.500000      rub    2270.00               4.0
# 19    1061.80000             0.200000      rub    1061.80               9.0
# 20     550.00000             0.100000      rub     550.00              18.0
# 21      57.90000             0.010000      rub     579.00              17.0
# 22     318.60000             0.050000      rub     318.60              31.0
# 23      32.57500             0.005000      rub    3257.50               3.0
# 24     397.35000             0.050000      rub     397.35              25.0
# 25     775.00000             0.100000      rub     775.00              12.0
# 26       0.77470             0.000100      rub     774.70              12.0
# 27      80.11000             0.010000      rub     801.10              12.0
# 28     155.86000             0.020000      rub    1558.60               6.0
# 29      42.00000             0.005000      rub     420.00              23.0
# 30      90.05000             0.010000      rub     900.50              11.0
# 31    4170.00000             0.500000      rub    4170.00               2.0
# 32    3828.00000             0.500000      rub    3828.00               2.0
# 33    1692.00000             0.200000      rub    1692.00               5.0
# 34    7000.00000             1.000000      rub    7000.00               1.0
# 35     116.97000             0.010000      rub    1169.70               8.0
# 36     123.27000             0.010000      rub    1232.70               8.0
# 37      12.30000             0.001000      rub    1230.00               8.0
# 38      64.89500             0.005000      rub     648.95              15.0
# 39     208.00000             0.010000      rub    2080.00               4.0
# 40   13400.00000             0.500000      rub   13400.00               0.0
# 41   19700.00000             2.000000      rub   19700.00               0.0
# 42  108150.00000            50.000000      rub  108150.00               0.0
#
#     profit
# 1     7.00
# 2     6.40
# 3     6.00
# 4     5.00
# 5     4.60
# 6     4.50
# 7     3.20
# 8     2.70
# 9     2.65
# 10    2.60
# 11    2.60
# 12    2.50
# 13    2.05
# 14    2.00
# 15    2.00
# 16    2.00
# 17    2.00
# 18    2.00
# 19    1.80
# 20    1.80
# 21    1.70
# 22    1.55
# 23    1.50
# 24    1.25
# 25    1.20
# 26    1.20
# 27    1.20
# 28    1.20
# 29    1.15
# 30    1.10
# 31    1.00
# 32    1.00
# 33    1.00
# 34    1.00
# 35    0.80
# 36    0.80
# 37    0.80
# 38    0.75
# 39    0.40
# 40    0.00
# 41    0.00
# 42    0.00

# %%
# https://ru.wikipedia.org/wiki/Голубые_фишки
moexbc = ['GAZP', 'SBER', 'LKOH', 'MGNT', 'NVTK', 'SNGS', 'GMKN', 
          'ROSN', 'NLMK', 'TATN', 'MTSS', 'ALRS', 'YNDX', 'FIVE', 'CHMF']

# %%
df[df['ticker'].isin(moexbc)]
# Out:
#                   name ticker          figi  lot     price  \
# 6   ГДР X5 RetailGroup   FIVE  BBG00JXPFBN0    1   1107.50
# 8             Татнефть   TATN  BBG004RVFFC0    1    359.70
# 12                 МТС   MTSS  BBG004S681W1   10    188.05
# 15             НОВАТЭК   NVTK  BBG00475KKY8    1    970.20
# 16      Сургутнефтегаз   SNGS  BBG0047315D0  100     22.69
# 19          Северсталь   CHMF  BBG00475K6C3    1   1061.80
# 24            Роснефть   ROSN  BBG004731354    1    397.35
# 27              АЛРОСА   ALRS  BBG004S68B31   10     80.11
# 28                НЛМК   NLMK  BBG004S681B4   10    155.86
# 31              Магнит   MGNT  BBG004RVFCY3    1   4170.00
# 32              ЛУКОЙЛ   LKOH  BBG004731032    1   3828.00
# 33              Yandex   YNDX  BBG006L8G4H1    1   1692.00
# 35           Сбер Банк   SBER  BBG004730N88   10    116.97
# 39             Газпром   GAZP  BBG004730RP0   10    208.00
# 41   Норильский никель   GMKN  BBG004731489    1  19700.00
#
#     min_price_increment currency  lot_price  shares_available  profit
# 6                 0.500      rub    1107.50               9.0    4.50
# 8                 0.100      rub     359.70              27.0    2.70
# 12                0.050      rub    1880.50               5.0    2.50
# 15                0.200      rub     970.20              10.0    2.00
# 16                0.005      rub    2269.00               4.0    2.00
# 19                0.200      rub    1061.80               9.0    1.80
# 24                0.050      rub     397.35              25.0    1.25
# 27                0.010      rub     801.10              12.0    1.20
# 28                0.020      rub    1558.60               6.0    1.20
# 31                0.500      rub    4170.00               2.0    1.00
# 32                0.500      rub    3828.00               2.0    1.00
# 33                0.200      rub    1692.00               5.0    1.00
# 35                0.010      rub    1169.70               8.0    0.80
# 39                0.010      rub    2080.00               4.0    0.40
# 41                2.000      rub   19700.00               0.0    0.00

# %%
# Стоимость IMOEX, если купить всего по одному лоту
df['lot_price'].sum()
# Out:
# 191062.7

# %%
# Стоимость MOEXBC, если купить всего по одному лоту
df[df['ticker'].isin(moexbc)]['lot_price'].sum()
# Out:
# 43045.45

# %%
df.to_csv('data.csv')

# %%
# # таблица в виде изображения
# # https://stackoverflow.com/a/39358752/10418812

# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import six

# df_print = df.copy()

# df_print = df_print[['name', 'ticker', 'min_price_increment', 'lot', 'price', 'shares_available', 'profit']]
# df_print['name'] = df_print['name'].apply(lambda x: x.replace('привилегированные', 'прив'))
# df_print['name'] = df_print['name'].apply(lambda x: x[:23])
# df_print['shares_available'] = df_print['shares_available'].astype(int)
# df_print['profit'] = df_print['profit'].round(5)
# cols = df_print.columns.to_list()
# df_print['N'] = df_print.index
# df_print = df_print[['N'] + cols]
# df_print.columns = ['Номер', 'Название', 'Тикет', 'Шаг цены', 'Кол-во акций в лоте', 'Цена', 'Кол-во акций', 'Прибыль за один шаг']

# def render_mpl_table(data, col_width=3.0, row_height=0.625, font_size=14,
#                      header_color='#40466e', row_colors=['#f1f1f2', 'w'], edge_color='w',
#                      bbox=[0, 0, 1, 1], header_columns=0,
#                      ax=None, **kwargs):
#     if ax is None:
#         size = (np.array(data.shape[::-1]) + np.array([0, 1])) * np.array([col_width, row_height])
#         fig, ax = plt.subplots(figsize=size)
#         ax.axis('off')

#     mpl_table = ax.table(cellText=data.values, bbox=bbox, colLabels=data.columns, **kwargs)

#     mpl_table.auto_set_font_size(False)
#     mpl_table.set_fontsize(font_size)

#     for k, cell in six.iteritems(mpl_table._cells):
#         cell.set_edgecolor(edge_color)
#         if k[0] == 0 or k[1] < header_columns:
#             cell.set_text_props(weight='bold', color='w')
#             cell.set_facecolor(header_color)
#         else:
#             cell.set_facecolor(row_colors[k[0]%len(row_colors) ])
            
#     return ax

# render_mpl_table(df_print, header_columns=0, col_width=3.7)
